# %%
import pandas as pd

# %%
#pindah head
df = pd.read_csv(r'D:\[KS6]\Python\dataset\Ikan_Cakalang.csv',header=0)
df2 = pd.read_csv(r'D:\[KS6]\Python\dataset\Ikan_Tuna.csv',header=0)

# %%
def drop_nan_by_count_column(data, count):
    nan_counts = data.isna().sum()

    # Get the column names where the count of NaN values is greater than 5
    columns_to_drop = nan_counts[nan_counts > count].index

    # Drop the columns from the DataFrame
    df = data.drop(columns_to_drop, axis=1)
    return df

# %%
#pindah head
# df = df.dropna(axis='rows')
# Count the number of NaN values in each column
# Out:
#          tanggal  harga_surabayakota  harga_malangkota  harga_banyuwangikab  \
# 0     2018-05-24               29500             28800                28000
# 1     2018-05-25               29500             28800                28000
# 2     2018-05-26               29500             28800                28000
# 3     2018-05-27               29500             28800                28000
# 4     2018-05-28               29500             28800                28000
# ...          ...                 ...               ...                  ...
# 1822  2023-05-20               41500             34666                32200
# 1823  2023-05-21               41500             34666                32200
# 1824  2023-05-22               41500             34833                32200
# 1825  2023-05-23               41500             34833                32200
# 1826  2023-05-24               41500             34833                32200
#
# ...

# %%
df.to_csv('Cakalang-14c.csv', index=False)
